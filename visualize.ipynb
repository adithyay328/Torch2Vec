# %%
import torch

# %%
myModel = torch.load("entire_model.dump")
VOCABSIZE = 5000

# %%
import vectorize
vec = vectorize.Vectorizer.load("vectorizer.dump")

# %%
# Getting a dict of word : numpy embedding
wordToNumpy = {}

with torch.no_grad():
    for token in vec.dictionary.token2id:
        id = vec.dictionary.token2id[token]

        oneHotDense = torch.zeros( (VOCABSIZE,) )
        oneHotDense[id + 1] = 1

        torchEmbedding = myModel.wordEmbedding(oneHotDense)
        numpyEmbedding = torchEmbedding.numpy()
        wordToNumpy[token] = numpyEmbedding
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/adithyay328/Documents/SoftwareProjects/Torch2Vec/visualize.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/adithyay328/Documents/SoftwareProjects/Torch2Vec/visualize.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> id = vec.dictionary.token2id[token]
#       <a href='vscode-notebook-cell:/home/adithyay328/Documents/SoftwareProjects/Torch2Vec/visualize.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> oneHotDense = torch.zeros( (VOCABSIZE,) )
# ----> <a href='vscode-notebook-cell:/home/adithyay328/Documents/SoftwareProjects/Torch2Vec/visualize.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> oneHotDense[id + 1] = 1
#      <a href='vscode-notebook-cell:/home/adithyay328/Documents/SoftwareProjects/Torch2Vec/visualize.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> torchEmbedding = myModel.wordEmbedding(oneHotDense)
#      <a href='vscode-notebook-cell:/home/adithyay328/Documents/SoftwareProjects/Torch2Vec/visualize.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> numpyEmbedding = torchEmbedding.numpy()
#
# IndexError: index 3000 is out of bounds for dimension 0 with size 3000

# %%
import pandas as pd
import plotly.express as px

words = [word for word in wordToNumpy]
arrays = [wordToNumpy[word] for word in wordToNumpy]

# %%
import sklearn.decomposition

pca = sklearn.decomposition.PCA(75)
pcaVectors = pca.fit_transform(arrays)

# %%
import sklearn.manifold

tsne = sklearn.manifold.TSNE(2, perplexity=15, early_exaggeration=20, learning_rate=700)
tsneVecs = tsne.fit_transform(pcaVectors)
# Out:
# /home/adithyay328/Documents/SoftwareProjects/Torch2Vec/venv/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.

# %%
xVals = tsneVecs.T[0]
yVals = tsneVecs.T[1]

# %%
df = pd.DataFrame(data={"words" : words, "x" : xVals, "y" : yVals})

# %%
fig = px.scatter(df, x="x", y="y", hover_data=["words"])
fig.show()
